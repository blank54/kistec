# %%
import sys
sys.path.append("/data/blank54/workspace/kistec/src/")
from visualize import PPMI

# %%
docs = [["I", "am", "a", "boy"],
        ["He", "is", "a", "boy"],
        ["She", "is", "a", "girl"]]

# %%
ppmi = PPMI(docs)

# %%
ppmi.compute()
# Out:
# Calculating Joint Probability 3/3
# Computing PPMI [ girl] x [   is]
#    word1 word2  ppmi_value
# 0      I    am       2.079
# 1    She  girl       2.079
# 2     He   boy       1.386
# 3     He    is       1.386
# 4      I   boy       1.386
# 5    She    is       1.386
# 6     am   boy       1.386
# 7     He     a       0.981
# 8      I     a       0.981
# 9    She     a       0.981
# 10     a   boy       0.981
# 11     a  girl       0.981
# 12    He     I       0.000
# 13    He   She       0.000
# 14    He    am       0.000
# 15    He  girl       0.000
# 16     I   She       0.000
# 17     I  girl       0.000
# 18     I    is       0.000
# 19   She    am       0.000
# 20   She   boy       0.000
# 21     a    am       0.000
# 22     a    is       0.000
# 23    am  girl       0.000
# 24    am    is       0.000
# 25   boy  girl       0.000
# 26   boy    is       0.000
# 27  girl    is       0.000
